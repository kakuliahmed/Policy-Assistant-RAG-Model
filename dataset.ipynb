# %%
import pandas as pd

df = pd.read_csv("C:/Users/firoz/OneDrive/Desktop/Policy-Assistant-RAG-Model/LIC.csv")
df.head()
# Out:
#                 Policy_Name                  Policy_ID  \
# 0          LIC’s Bima Jyoti  Plan 860 / UIN 512N339V02
# 1          LIC’s Bima Ratna  Plan 864 / UIN 512N345V01
# 2        LIC’s Dhan Sanchay  Plan 865 / UIN 512N346V01
# 3  LIC’s New Endowment Plan  Plan 914 / UIN 512N277V02
# 4    LIC’s New Jeevan Anand  Plan 915 / UIN 512N279V02
#
#                                          Description  \
# 0  Non-linked, non-participating individual endow...
# 1  Non-linked, non-participating, individual, sav...
# 2  Non-linked, non-participating, individual savi...
# 3  Participating non-linked endowment plan provid...
# 4  Participating endowment plan combining savings...
#
#                                             Duration
# 0  Policy term 15–20 years; premium paying term g...
# 1  Policy term typically 15–20 years with limited...
# 2  Policy term options usually 10–20 years depend...
# 3  Policy term usually 12–35 years depending on a...
# ...

# %%
documents = []
metadatas = []
ids = []

for i, row in df.iterrows():
    document = f"{row['Policy_Name']} - {row['Description']} - {row['Duration']}"
    
    metadata = {
        "Policy_Name": row["Policy_Name"],
        "Policy_ID": row["Policy_ID"],
        "Description": row["Description"],
        "Duration": row["Duration"]
    }

    documents.append(document)
    metadatas.append(metadata)
    ids.append(str(i+1))

len(documents), len(metadatas), len(ids)
# Out:
# (37, 37, 37)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-mpnet-base-v2")
print("Embedding model loaded ✔")

# %%
import chromadb
from chromadb.utils import embedding_functions

embedding_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-mpnet-base-v2"
)

# Create local DB folder
client = chromadb.PersistentClient(path="lic_vector_db")

# optional: reset collection if exists
# client.delete_collection("lic_policies")

collection = client.get_or_create_collection(
    name="lic_policies",
    embedding_function=embedding_fn
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 import chromadb
#       2 from chromadb.utils import embedding_functions
# ----> 4 embedding_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
#       5     model_name="all-mpnet-base-v2"
#       6 )
#       8 # Create local DB folder
#       9 client = chromadb.PersistentClient(path="lic_vector_db")
#
# ...
